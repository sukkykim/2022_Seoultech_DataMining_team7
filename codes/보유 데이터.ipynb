# %% [markdown]
# # 보유데이터
# - 종속변수 : 서울시 골목상권의 분기별 매출
# - 독립변수 후보 : 상권과 배후지에 대한 생활인구, 직장인구, 아파트, 소득소비 등의 다양한 변수

# %% [markdown]
# ### 서울시 골목상권의 분기별 매출(2017~2021)
# - 기준년도와 분기, 상권코드등으로 행을 구분하며, 총매출을 사용할 예정

# %%
import pandas as pd
target = pd.read_csv('D:/데이터마이닝_데이터/상권_정리/전체구/매출/골목상권매출_17-21.csv', encoding='cp949')

# %%
target
# Out:
#        기준_년_코드  기준_분기_코드 상권_구분_코드_명    상권_코드          총매출
# 0         2021         4       골목상권  2111090   6164144274
# 1         2021         4       골목상권  2111089  18215725779
# 2         2021         4       골목상권  2111088   3130903256
# 3         2021         4       골목상권  2111087   2770689276
# 4         2021         4       골목상권  2111086   4831084227
# ...        ...       ...        ...      ...          ...
# 21792     2017         4       골목상권  2111086   5443196939
# 21793     2017         4       골목상권  2111087   2608250578
# 21794     2017         4       골목상권  2111088   4298428387
# 21795     2017         4       골목상권  2111089  11780952910
# 21796     2017         4       골목상권  2111090  11375071506
#
# [21797 rows x 5 columns]

# %% [markdown]
# ### 독립변수 후보
# - 년도, 분기, 상권코드로 매추출과 매칭시킴
# - 한주제에 대해 해당하는 변수들이 들어있음

# %%
x1 = pd.read_csv('D:/데이터마이닝_데이터/상권_정리/서울시 우리마을가게 상권분석서비스(상권-아파트).csv', encoding='cp949')

# %%
x1
# Out:
#        기준_년_코드  기준_분기_코드 상권_구분_코드 상권_구분_코드_명    상권_코드       상권_코드_명  아파트_단지_수  \
# 0         2021         4        R       전통시장  2130326     고덕 골목형상점가         1
# 1         2021         3        R       전통시장  2130326     고덕 골목형상점가         1
# 2         2021         2        R       전통시장  2130326     고덕 골목형상점가         1
# 3         2021         1        R       전통시장  2130326     고덕 골목형상점가         1
# 4         2021         4        R       전통시장  2130325        명일전통시장         5
# ...        ...       ...      ...        ...      ...           ...       ...
# 29178     2017         1        U       관광특구  1001493  동대문패션타운 관광특구         9
# 29179     2017         4        U       관광특구  1001491      이태원 관광특구        69
# 29180     2017         3        U       관광특구  1001491      이태원 관광특구        69
# 29181     2017         2        U       관광특구  1001491      이태원 관광특구        69
# 29182     2017         1        U       관광특구  1001491      이태원 관광특구        69
#
# ...

# %%
x2 = pd.read_csv('D:/데이터마이닝_데이터/상권_정리/서울시 우리마을가게 상권분석서비스(상권-생활인구).csv', encoding='cp949')

# %%
x2
# Out:
#        기준 년코드  기준_분기_코드 상권_구분_코드  상권_구분_코드_명    상권_코드                 상권_코드_명  \
# 0        2021         4        U        관광특구  1001496             강남 마이스 관광특구
# 1        2021         4        U        관광특구  1001495                 잠실 관광특구
# 2        2021         4        U        관광특구  1001494              종로?청계 관광특구
# 3        2021         4        U        관광특구  1001493            동대문패션타운 관광특구
# 4        2021         4        U        관광특구  1001492  명동 남대문 북창동 다동 무교동 관광특구
# ...       ...       ...      ...         ...      ...                     ...
# 33362    2017         1        A        골목상권  2110005                     세검정
# 33363    2017         1        A        골목상권  2110004                  대신고등학교
# 33364    2017         1        A        골목상권  2110003                 세검정초등학교
# 33365    2017         1        A        골목상권  2110002                 독립문역 1번
# 33366    2017         1        A        골목상권  2110001                  이북5도청사
#
# ...

# %%
x3 = pd.read_csv('D:/데이터마이닝_데이터/상권_정리/전체구/서울시 우리마을가게 상권분석서비스(상권-직장인구).csv', encoding='cp949')

# %%
x3
# Out:
#        기준_년월_코드  기준_분기_코드 상권_구분_코드 상권_구분_코드_명    상권_코드  \
# 0          2021         4        U       관광특구  1001496
# 1          2021         4        U       관광특구  1001495
# 2          2021         4        U       관광특구  1001494
# 3          2021         4        U       관광특구  1001493
# 4          2021         4        U       관광특구  1001492
# ...         ...       ...      ...        ...      ...
# 31219      2017         2        A       골목상권  2110005
# 31220      2017         2        A       골목상권  2110004
# 31221      2017         2        A       골목상권  2110003
# 31222      2017         2        A       골목상권  2110002
# 31223      2017         2        A       골목상권  2110001
#
#                       상권_코드_명  총_직장_인구_수  남성_직장_인구_수  여성_직장_인구_수  \
# 0                 강남 마이스 관광특구      15904        8904        7000
# 1                     잠실 관광특구      24375       14199       10176
# 2                  종로?청계 관광특구      32935       17150       15785
# ...

# %%
x4 = pd.read_csv('D:/데이터마이닝_데이터/상권_정리/전체구/서울시 우리마을가게 상권분석서비스(상권배후지-상주인구).csv', encoding='cp949')

# %%
x4
# Out:
#        기준_년_코드  기준_분기_코드 상권_구분_코드 상권_구분_코드_명    상권_코드          상권_코드_명  \
# 0         2021         4        A       골목상권  2111090          강일동주민센터
# 1         2021         4        A       골목상권  2111089     상일여고(상일초등학교)
# 2         2021         4        A       골목상권  2111088            고덕동성당
# 3         2021         4        A       골목상권  2111087  고덕중학교(고덕2동주민센터)
# 4         2021         4        A       골목상권  2111086             한영중고
# ...        ...       ...      ...        ...      ...              ...
# 21795     2017         1        A       골목상권  2110005              세검정
# 21796     2017         1        A       골목상권  2110004           대신고등학교
# 21797     2017         1        A       골목상권  2110003          세검정초등학교
# 21798     2017         1        A       골목상권  2110002          독립문역 1번
# 21799     2017         1        A       골목상권  2110001           이북5도청사
#
#        총_상주인구_수  남성_상주인구_수  여성_상주인구_수  연령대_10_상주인구_수  ...  남성연령대_60_이상_상주인구_수  \
# ...

# %%
x5 = pd.read_csv('D:/데이터마이닝_데이터/상권_정리/전체구/서울시 우리마을가게 상권분석서비스(상권-소득소비).csv', encoding='cp949')

# %%
x5
# Out:
#        기준_년_코드  기준_분기_코드 상권_구분_코드 상권_구분_코드_명    상권_코드                 상권_코드_명  \
# 0         2021         4        A       골목상권  2110001                  이북5도청사
# 1         2021         4        A       골목상권  2110002                 독립문역 1번
# 2         2021         4        A       골목상권  2110003                 세검정초등학교
# 3         2021         4        A       골목상권  2110004                  대신고등학교
# 4         2021         4        A       골목상권  2110005                     세검정
# ...        ...       ...      ...        ...      ...                     ...
# 32557     2017         1        U       관광특구  1001492  명동 남대문 북창동 다동 무교동 관광특구
# 32558     2017         1        U       관광특구  1001493            동대문패션타운 관광특구
# 32559     2017         1        U       관광특구  1001494              종로?청계 관광특구
# 32560     2017         1        U       관광특구  1001495                 잠실 관광특구
# 32561     2017         1        U       관광특구  1001496             강남 마이스 관광특구
#
# ...

# %% [markdown]
# 이외의 상권데이터를 통해 분석을 진행할 예정
