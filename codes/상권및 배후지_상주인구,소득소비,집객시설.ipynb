# %% [markdown]
# 상권_상주인구,소득소비,집객시설, 상권배후지_상주인구,소득소비,집객시설 데이터 파악 및 각 변수별 상관계수파악

# %%
import pandas as pd

# %% [markdown]
# -상권_상주인구

# %%
dataset1=pd.read_csv('상주인구_상권.csv',index_col=0)
dataset1
# Out:
#           남성 상주인구 수  여성 상주인구 수  연령대 10 상주인구 수  연령대 20 상주인구 수  연령대 30 상주인구 수  \
# 총 상주인구 수
# 1002            537        465             45            271            232
# 3663           1871       1792            426            547            432
# 1940           1001        939            202            254            198
# 2415           1285       1130            302            308            290
# 2403           1173       1230            452            314            279
# ...             ...        ...            ...            ...            ...
# 1940            941        999            352            265            228
# 534             262        272             82             58             59
# 3337           1627       1710            618            526            399
# 680             335        345             92             53             69
# 1211            574        637            214            173            110
#
# ...

# %%
corr=dataset1.corr(method='pearson')
print(corr)
# Out:
#                     남성 상주인구 수  여성 상주인구 수  연령대 10 상주인구 수  연령대 20 상주인구 수  \
# 남성 상주인구 수            1.000000   0.990024       0.931592       0.905204
# 여성 상주인구 수            0.990024   1.000000       0.944875       0.897266
# 연령대 10 상주인구 수        0.931592   0.944875       1.000000       0.767750
# 연령대 20 상주인구 수        0.905204   0.897266       0.767750       1.000000
# 연령대 30 상주인구 수        0.941984   0.947178       0.862054       0.921172
# 연령대 40 상주인구 수        0.982242   0.986153       0.968711       0.847520
# 연령대 50 상주인구 수        0.972845   0.966967       0.929394       0.806782
# 연령대 60 이상 상주인구 수     0.952852   0.949207       0.877652       0.794012
# 남성연령대 10 상주인구 수      0.930183   0.941278       0.997805       0.763888
# 남성연령대 20 상주인구 수      0.911823   0.888359       0.772980       0.987300
# 남성연령대 30 상주인구 수      0.945722   0.937699       0.843858       0.931677
# 남성연령대 40 상주인구 수      0.988357   0.980675       0.948923       0.859632
# ...

# %% [markdown]
# -상권배후지_상주인구

# %%
dataset2=pd.read_csv('상주인구_상권배후지.csv',index_col=0)
dataset2
# Out:
#           남성_상주인구_수  여성_상주인구_수  연령대_10_상주인구_수  연령대_20_상주인구_수  연령대_30_상주인구_수  \
# 총_상주인구_수
# 6033           2953       3080           1151            734            789
# 11533          5759       5774           2269           1427           1723
# 12677          6247       6430           2302           1691           2141
# 8423           4354       4069           1570            918           1452
# 11672          5758       5914           2516           1385           1194
# ...             ...        ...            ...            ...            ...
# 9332           4502       4830           1574           1378           1186
# 12241          5805       6436           2190           1447           1481
# 11449          5548       5901           2066           1668           1316
# 8409           3989       4420           1717            975            980
# 5797           2803       2994           1047            846            649
#
# ...

# %%
corr=dataset2.corr(method='pearson')
print(corr)
# Out:
#                     남성_상주인구_수  여성_상주인구_수  연령대_10_상주인구_수  연령대_20_상주인구_수  \
# 남성_상주인구_수            1.000000   0.990977       0.889744       0.881278
# 여성_상주인구_수            0.990977   1.000000       0.905231       0.875714
# 연령대_10_상주인구_수        0.889744   0.905231       1.000000       0.673069
# 연령대_20_상주인구_수        0.881278   0.875714       0.673069       1.000000
# 연령대_30_상주인구_수        0.923883   0.928103       0.782686       0.901664
# 연령대_40_상주인구_수        0.970865   0.977692       0.955378       0.799737
# 연령대_50_상주인구_수        0.972604   0.963541       0.879823       0.786395
# 연령대_60_이상_상주인구_수     0.940618   0.934025       0.790479       0.766490
# 남성연령대_10_상주인구_수      0.888663   0.901832       0.998022       0.670530
# 남성연령대_20_상주인구_수      0.900667   0.881327       0.695746       0.987527
# 남성연령대_30_상주인구_수      0.925204   0.916076       0.748345       0.915983
# 남성연령대_40_상주인구_수      0.982052   0.978579       0.932250       0.818200
# ...

# %% [markdown]
# -상권_소득소비

# %%
dataset3=pd.read_excel('소득소비_상권.xlsx',index_col=0)
dataset3
# Out:
#             소득_구간_코드        지출_총금액   식료품_지출_총금액  의류_신발_지출_총금액  생활용품_지출_총금액  \
# 월_평균_소득_금액
# 4305934.0        8.0  5.204276e+08  129126028.0    64853632.0   37122367.0
# 3463885.0        7.0  2.324652e+08   54998987.0    28932090.0   17084860.0
# 3548020.0        7.0  1.349699e+09  336704220.0   166150296.0   98720958.0
# 2644953.0        6.0  7.127728e+08  205649728.0    84170011.0   51668351.0
# 3703145.0        7.0  8.847016e+08  221446948.0   109882417.0   64738346.0
# ...              ...           ...          ...           ...          ...
# 2738996.0        6.0  2.610705e+09  719044027.0   309668608.0  172130484.0
# 2454275.0        6.0  2.233502e+09  602589622.0   273641316.0  156144875.0
# 2377027.0        5.0  1.852874e+09  525723559.0   219603615.0  126050307.0
# 2459152.0        6.0  1.881897e+09  521115964.0   223526874.0  126199665.0
# 2915084.0        6.0           NaN          NaN           NaN          NaN
#
# ...

# %%
corr=dataset3.corr(method='pearson')
print(corr)
# Out:
#               소득_구간_코드    지출_총금액  식료품_지출_총금액  의류_신발_지출_총금액  생활용품_지출_총금액  \
# 소득_구간_코드      1.000000 -0.111648   -0.153069     -0.099887    -0.097895
# 지출_총금액       -0.111648  1.000000    0.993799      0.999073     0.997192
# 식료품_지출_총금액   -0.153069  0.993799    1.000000      0.989933     0.989381
# 의류_신발_지출_총금액 -0.099887  0.999073    0.989933      1.000000     0.997702
# 생활용품_지출_총금액  -0.097895  0.997192    0.989381      0.997702     1.000000
# 의료비_지출_총금액   -0.154296  0.994230    0.998973      0.990343     0.988246
# 교통_지출_총금액    -0.086212  0.995537    0.982456      0.994641     0.994102
# 여가_지출_총금액    -0.070020  0.990092    0.974906      0.992567     0.992838
# 문화_지출_총금액    -0.120683  0.994026    0.991405      0.995190     0.993680
# 교육_지출_총금액    -0.056157  0.984034    0.960833      0.986431     0.978975
# 유흥_지출_총금액    -0.102942  0.997522    0.988717      0.999038     0.995926
#
#               의료비_지출_총금액  교통_지출_총금액  여가_지출_총금액  문화_지출_총금액  교육_지출_총금액  \
# ...

# %% [markdown]
# -상권배후지_소득소비

# %%
dataset4=pd.read_excel('소득소비_상권배후지.xlsx',index_col=0)
dataset4
# Out:
#             소득_구간_코드       지출_총금액  식료품_지출_총금액  의류_신발_지출_총금액  생활용품_지출_총금액  \
# 월_평균_소득_금액
# 2729716            6   7501923026  2151712515     888933146    553108402
# 3355209            7  11842475922  3099929654    1428912815    849935987
# 3338064            7   6179246740  1683952466     733874296    430168476
# 2416795            5   5235197988  1501033989     616414129    374450525
# 2956757            6   4803914725  1364476852     574723444    344562961
# ...              ...          ...         ...           ...          ...
# 3355245            7  10480102168  2702974167    1259814094    733686903
# 4925972            9  10828981523  2440776408    1357821501    847072765
# 4839505            8  10573001959  2400266781    1302676115    804638128
# 3126202            7   7588403485  1968064770     909705378    545863933
# 3276452            7  11038024794  2758053650    1331892881    799060966
#
#             의료비_지출_총금액   교통_지출_총금액  여가_지출_총금액  문화_지출_총금액   교육_지출_총금액  \
# ...

# %%
corr=dataset4.corr(method='pearson')
print(corr)
# Out:
#               소득_구간_코드    지출_총금액  식료품_지출_총금액  의류_신발_지출_총금액  생활용품_지출_총금액  \
# 소득_구간_코드      1.000000 -0.138888   -0.225858     -0.124707    -0.130958
# 지출_총금액       -0.138888  1.000000    0.981693      0.997665     0.991449
# 식료품_지출_총금액   -0.225858  0.981693    1.000000      0.970945     0.965237
# 의류_신발_지출_총금액 -0.124707  0.997665    0.970945      1.000000     0.994553
# 생활용품_지출_총금액  -0.130958  0.991449    0.965237      0.994553     1.000000
# 의료비_지출_총금액   -0.222255  0.982560    0.997660      0.971597     0.963118
# 교통_지출_총금액    -0.078348  0.989823    0.952368      0.989085     0.986207
# 여가_지출_총금액    -0.084149  0.974516    0.929875      0.982120     0.984278
# 문화_지출_총금액    -0.185775  0.984682    0.976106      0.987335     0.984824
# 교육_지출_총금액    -0.012779  0.961375    0.899700      0.966367     0.949550
# 유흥_지출_총금액    -0.126152  0.994411    0.969242      0.997712     0.990627
#
#               의료비_지출_총금액  교통_지출_총금액  여가_지출_총금액  문화_지출_총금액  교육_지출_총금액  \
# ...

# %% [markdown]
# -상권_집객시설

# %%
dataset5=pd.read_excel('b.xlsx',index_col=0)
dataset5
# Out:
#         관공서_수  은행_수  의료기관_수  교육기관_수  상점_수  극장_수  숙박_시설_수  교통기관_수
# 집객시설_수
# 23        NaN   NaN       6       1     0   NaN      NaN       5
# 1         NaN   NaN       0       0     0   NaN      NaN       0
# 2         NaN   NaN       0       0     0   NaN      NaN       0
# 1         NaN   NaN       0       0     0   NaN      NaN       0
# 11        NaN   NaN       0       1     0   NaN      NaN       5
# ...       ...   ...     ...     ...   ...   ...      ...     ...
# 5         NaN   NaN       1       0     0   NaN      NaN       0
# 10        NaN   NaN       3       0     0   NaN      1.0       1
# 3         NaN   NaN       0       1     1   NaN      NaN       1
# 2         NaN   NaN       0       0     0   NaN      NaN       2
# 13        NaN   NaN       0       0     0   NaN      NaN      12
#
# [20963 rows x 8 columns]

# %%
corr=dataset5.corr(method='pearson')
print(corr)
# Out:
#             관공서_수      은행_수    의료기관_수    교육기관_수      상점_수      극장_수   숙박_시설_수  \
# 관공서_수    1.000000  0.161663  0.105761  0.037052  0.105043  0.292254 -0.064351
# 은행_수     0.161663  1.000000  0.084998 -0.022163  0.051801 -0.090391  0.037799
# 의료기관_수   0.105761  0.084998  1.000000  0.174153  0.107557 -0.100710  0.051713
# 교육기관_수   0.037052 -0.022163  0.174153  1.000000  0.014804  0.048487  0.003037
# 상점_수     0.105043  0.051801  0.107557  0.014804  1.000000 -0.034796 -0.013142
# 극장_수     0.292254 -0.090391 -0.100710  0.048487 -0.034796  1.000000  0.533648
# 숙박_시설_수 -0.064351  0.037799  0.051713  0.003037 -0.013142  0.533648  1.000000
# 교통기관_수   0.145743  0.031163  0.391193  0.175366  0.072291  0.324992  0.131955
#
#            교통기관_수
# 관공서_수    0.145743
# 은행_수     0.031163
# 의료기관_수   0.391193
# 교육기관_수   0.175366
# 상점_수     0.072291
# 극장_수     0.324992
# 숙박_시설_수  0.131955
# 교통기관_수   1.000000

# %% [markdown]
# -상권배후지_집객시설

# %%
dataset6=pd.read_excel('a.xlsx',index_col=0)
dataset6
# Out:
#         관공서_수  은행_수  의료기관_수  교육기관_수  상점  극장_수  숙박_시설_수  교통기관_수
# 집객시설_수
# 85        3.0   2.0      12       4   0   NaN      NaN      15
# 35        1.0   1.0       5       2   0   NaN      NaN      16
# 55        2.0   1.0       4      21   0   NaN      NaN      13
# 26        2.0   NaN       0       1   0   NaN      NaN      10
# 80        3.0   1.0      13       0   1   NaN      1.0      17
# ...       ...   ...     ...     ...  ..   ...      ...     ...
# 47        1.0   2.0       1       8   0   NaN      1.0      29
# 28        3.0   1.0       1       4   0   2.0      NaN      15
# 71        1.0   1.0      11       2   1   1.0      9.0      15
# 68        2.0   3.0       8      11   0   3.0      3.0      21
# 14        1.0   1.0       0       1   0   NaN      1.0      10
#
# [21800 rows x 8 columns]

# %%
corr=dataset6.corr(method='pearson')
print(corr)
# Out:
#             관공서_수      은행_수    의료기관_수    교육기관_수        상점      극장_수   숙박_시설_수  \
# 관공서_수    1.000000  0.260291  0.194511  0.058525  0.070671  0.209436  0.111281
# 은행_수     0.260291  1.000000  0.405503 -0.005131  0.129921  0.098043  0.255555
# 의료기관_수   0.194511  0.405503  1.000000  0.048280  0.240725 -0.100919  0.193834
# 교육기관_수   0.058525 -0.005131  0.048280  1.000000 -0.014646  0.069350  0.141689
# 상점       0.070671  0.129921  0.240725 -0.014646  1.000000 -0.056322  0.058361
# 극장_수     0.209436  0.098043 -0.100919  0.069350 -0.056322  1.000000  0.243230
# 숙박_시설_수  0.111281  0.255555  0.193834  0.141689  0.058361  0.243230  1.000000
# 교통기관_수   0.268416  0.177536  0.395268  0.152308  0.156877  0.106543  0.169182
#
#            교통기관_수
# 관공서_수    0.268416
# 은행_수     0.177536
# 의료기관_수   0.395268
# 교육기관_수   0.152308
# 상점       0.156877
# 극장_수     0.106543
# 숙박_시설_수  0.169182
# 교통기관_수   1.000000
